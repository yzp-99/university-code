# %%
# 2
import nltk
from nltk.corpus import brown
fdist1 = FreqDist(text4)
fdist1
# Out:
# FreqDist({'Fellow': 24,
#           '-': 290,
#           'Citizens': 7,
#           'of': 7087,
#           'the': 9446,
#           'Senate': 11,
#           'and': 5146,
#           'House': 8,
#           'Representatives': 5,
#           ':': 137,
#           'Among': 4,
#           'vicissitudes': 5,
#           'incident': 8,
#           'to': 4414,
#           'life': 139,
#           'no': 416,
#           'event': 16,
#           'could': 71,
#           'have': 1008,
#           'filled': 6,
#           'me': 186,
#           'with': 906,
#           'greater': 53,
#           'anxieties': 3,
#           'than': 240,
#           'that': 1748,
#           'which': 1006,
#           'notification': 1,
#           'was': 270,
#           'transmitted': 3,
#           'by': 1053,
#           'your': 114,
#           'order': 64,
#           ',': 7045,
#           'received': 12,
#           'on': 509,
#           '14th': 1,
#           'day': 91,
#           'present': 85,
# ...

# %%
fdist1['dream']
# Out:
# 17

# %%
#  3
import nltk
s='They wind back the clock,while we chase after the wind'
s1=nltk.word_tokenize(s)
s2=nltk.pos_tag(s1) #list类型
s2
# Out:
# [('They', 'PRP'),
#  ('wind', 'VBP'),
#  ('back', 'RB'),
#  ('the', 'DT'),
#  ('clock', 'NN'),
#  (',', ','),
#  ('while', 'IN'),
#  ('we', 'PRP'),
#  ('chase', 'VBP'),
#  ('after', 'IN'),
#  ('the', 'DT'),
#  ('wind', 'NN')]

# %%
#  4
#答：钥匙对应锁，学生对应学号，电影票对应座位。从虚拟信息映射到实物，或从具体到抽象。

# %%
# 6
d={}
d
# Out:
# {}

# %%
d ['abc']='ADJ'
d ['fat']='JJ'
d ['kiss']= 'NN'
d
# Out:
# {'abc': 'ADJ', 'fat': 'JJ', 'kiss': 'NN'}

# %%
del d['abc']

# %%
d
# Out:
# {'fat': 'JJ', 'kiss': 'NN'}

# %%
# 7
d1={'blue':'JJ','strong':'JJ','tree':'NN'}
d1
# Out:
# {'blue': 'JJ', 'strong': 'JJ', 'tree': 'NN'}

# %%
d2 ={'red':'JJ','shy':'JJ','sky':'NN'}
d2
# Out:
# {'red': 'JJ', 'shy': 'JJ', 'sky': 'NN'}

# %%
d1.update(d2)

# %%
d1
# Out:
# {'blue': 'JJ',
#  'red': 'JJ',
#  'shy': 'JJ',
#  'sky': 'NN',
#  'strong': 'JJ',
#  'tree': 'NN'}

# %%
d2
# Out:
# {'red': 'JJ', 'shy': 'JJ', 'sky': 'NN'}

# %%
# 8
e ={'headword':'NN','part-of-speech':'NN','sence':'NN','example':'NN'}
e
# Out:
# {'example': 'NN', 'headword': 'NN', 'part-of-speech': 'NN', 'sence': 'NN'}

# %%
# 9
from nltk.book import *
text1.concordance('go')
text1.concordance('went')
# Out:
# Displaying 25 of 194 matches:
# by so much the more shall ye for ever go thankless ! Would that I could clear
# wallow up Jonah ." -- JONAH . " There go the ships ; there is that Leviathan w
# ur children ' s grand - children will go for bread ." -- OBED MACY ' S HISTORY
#  city of a dreamy Sabbath afternoon . Go from Corlears Hook to Coenties Slip ,
# ed upon the magic stream before him . Go visit the Prairies in June , when for
#  him , at some time or other crazy to go to sea ? Why upon your first voyage a
#  mean to have it inferred that I ever go to sea as a passenger . For to go as
# ver go to sea as a passenger . For to go as a passenger you must needs have a
# , as a general thing ;-- no , I never go as a passenger ; nor , though I am so
#  I am something of a salt , do I ever go to sea as a Commodore , or a Captain
# e - houses the pyramids . No , when I go to sea , I go as a simple sailor , ri
#  pyramids . No , when I go to sea , I go as a simple sailor , right before the
# ...

# %%
# 10
from nltk.corpus import brown
brown_tagged_sents =brown.tagged_sents(categories='lore')
brown_sents =brown.sents(categories='lore')
unigram_tagger = nltk.UnigramTagger(brown_tagged_sents)
unigram_tagger.tag(brown_sents[2009])
# Out:
# [('As', 'CS'),
#  ('promptly', 'RB'),
#  ('as', 'CS'),
#  ('Torrio', 'NP'),
#  (',', ','),
#  ("O'Banion", 'NP'),
#  ('jumped', 'VBD'),
#  ('into', 'IN'),
#  ('bootlegging', 'VBG'),
#  ('.', '.')]

# %%
# 11
import nltk

from nltk.corpus import brown

brown_sents=brown.sents(categories='news')

brown_tagged_sents=brown.tagged_sents(categories='news')

affixtagger=nltk.AffixTagger(brown_tagged_sents)

affixtagger.tag(brown_sents[2007])
# Out:
# [('Various', 'JJ'),
#  ('of', None),
#  ('the', None),
#  ('apartments', 'NNS'),
#  ('are', None),
#  ('of', None),
#  ('the', None),
#  ('terrace', 'NN'),
#  ('type', None),
#  (',', None),
#  ('being', 'VBG'),
#  ('on', None),
#  ('the', None),
#  ('ground', 'NN'),
#  ('floor', 'NN'),
#  ('so', None),
#  ('that', None),
#  ('entrance', 'NN'),
#  ('is', None),
#  ('direct', 'NN'),
#  ('.', None)]

# %%
# 12
import nltk

from nltk.corpus import brown

brown_sents=brown.sents(categories='news')

brown_tagged_sents=brown.tagged_sents(categories='news')

bigram_tagger=nltk.BigramTagger(brown_tagged_sents)

bigram_tagger.tag(brown_sents[2007])

bigram_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.7892972929967977

# %%
# 13
k={'year':2019,'month':11,'day':19}

print ('%s-%s-%s' %( k['year'],k['month'],k['day']))
# Out:
# 2019-11-19

# %%
# 14
import nltk

from nltk.corpus import brown

sorted(set(brown.words(categories='news')))
# Out:
# ['!',
#  '$1',
#  '$1,000',
#  '$1,000,000,000',
#  '$1,500',
#  '$1,500,000',
#  '$1,600',
#  '$1,800',
#  '$1.1',
#  '$1.4',
#  '$1.5',
#  '$1.80',
#  '$10',
#  '$10,000',
#  '$10,000-per-year',
#  '$100',
#  '$100,000',
#  '$102,285,000',
#  '$109',
#  '$11.50',
#  '$115,000',
#  '$12',
#  '$12,192,865',
#  '$12,500',
#  '$12.50',
#  '$12.7',
#  '$120',
#  '$125',
#  '$135',
#  '$139.3',
#  '$14',
#  '$15',
#  '$15,000',
#  '$15,000,000',
#  '$150',
#  '$157,460',
#  '$16',
#  '$16,000',
#  '$17',
#  '$17,000',
#  '$17.8',
#  '$172,000',
#  '$172,400',
#  '$18',
#  '$18.2',
#  '$18.9',
#  '$2',
#  '$2,000',
#  '$2,170',
#  '$2,330,000',
#  '$2,700',
#  '$2.50',
#  '$2.80',
#  '$20',
#  '$20,000',
#  '$20,447,000',
#  '$200,000',
#  '$214',
#  '$22',
#  '$22.50',
#  '$2400',
#  '$25',
#  '$25,000',
#  '$25-a-plate',
#  '$250',
#  '$250,000',
#  '$251',
#  '$253,355,000',
#  '$26,000,000',
#  '$278,877,000',
#  '$28',
#  '$28,700,000',
#  '$29,000',
#  '$3',
#  '$3,500',
# ...

# %%
# 31
import nltk
import pylab
from nltk.corpus import brown
def performance(cfd, wordlist):
    lt = dict((word, cfd[word].max())for word in wordlist)
    baseline_tagger = nltk.UnigramTagger(model=lt, backoff=nltk.DefaultTagger('NN'))
    return baseline_tagger.evaluate(brown.tagged_sents(categories='news'))

def display():
    
    words_by_freq=list(nltk.FreqDist(brown.words(categories='news')))
    cfd = nltk.ConditionalFreqDist(brown.tagged_words(categories='news'))
    sizes = 2 ** pylab.arange(15)
    perfs = [performance(cfd, words_by_freq[:size])for size in sizes]
    pylab.semilogx(sizes, perfs, '-bo')
    pylab.title('Lookup Tagger Performance with Varying Model Size')
    pylab.xlabel('Model Size')
    pylab.ylabel('Performance')
    pylab.show()
display()

# %%
# 32
import nltk
from nltk.tag import brill
brill.nltkdemo18plus()
brill.nltkdemo18()
# Out:
# [Template(Pos([-1])),
#  Template(Pos([1])),
#  Template(Pos([-2])),
#  Template(Pos([2])),
#  Template(Pos([-2, -1])),
#  Template(Pos([1, 2])),
#  Template(Pos([-3, -2, -1])),
#  Template(Pos([1, 2, 3])),
#  Template(Pos([-1]),Pos([1])),
#  Template(Word([-1])),
#  Template(Word([1])),
#  Template(Word([-2])),
#  Template(Word([2])),
#  Template(Word([-2, -1])),
#  Template(Word([1, 2])),
#  Template(Word([-3, -2, -1])),
#  Template(Word([1, 2, 3])),
#  Template(Word([-1]),Word([1]))]

# %%
# 36
import nltk
# Unigram
fd = nltk.FreqDist(brown.words(categories='news'))
cfd = nltk.ConditionalFreqDist(brown.tagged_words(categories='news'))
most_freq_words = fd.most_common(100)
likely_tags = dict((word, cfd[word].max()) for (word, _) in most_freq_words)
baseline_tagger = nltk.UnigramTagger(model=likely_tags)
baseline_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.45578495136941344

# %%
# 正则
patterns = [
  (r'.*ing$', 'VBG'),               
  (r'.*ed$', 'VBD'),                
 (r'.*es$', 'VBZ'),                
 (r'.*ould$', 'MD'),               
(r'.*\'s$', 'NN$'),            
 (r'.*s$', 'NNS'),                 
 (r'^-?[0-9]+(.[0-9]+)?$', 'CD'),  
 (r'.*', 'NN')                     
]
regexp_tagger = nltk.RegexpTagger(patterns)
regexp_tagger.tag(brown_sents[3])

regexp_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.20326391789486245

# %%
# 一元标注器
from nltk.corpus import brown
brown_tagged_sents = brown.tagged_sents(categories='news')
brown_sents = brown.sents(categories='news')
unigram_tagger = nltk.UnigramTagger(brown_tagged_sents)
unigram_tagger.tag(brown_sents[2007])
# Out:
# [('Various', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('apartments', 'NNS'),
#  ('are', 'BER'),
#  ('of', 'IN'),
#  ('the', 'AT'),
#  ('terrace', 'NN'),
#  ('type', 'NN'),
#  (',', ','),
#  ('being', 'BEG'),
#  ('on', 'IN'),
#  ('the', 'AT'),
#  ('ground', 'NN'),
#  ('floor', 'NN'),
#  ('so', 'QL'),
#  ('that', 'CS'),
#  ('entrance', 'NN'),
#  ('is', 'BEZ'),
#  ('direct', 'JJ'),
#  ('.', '.')]

# %%
unigram_tagger.evaluate(brown_tagged_sents)
# Out:
# 0.9349006503968017

# %%
# 26
import nltk
import pylab
from nltk.corpus import brown
def performance(cfd, wordlist):
    lt = dict((word, cfd[word].max())for word in wordlist)
    baseline_tagger = nltk.UnigramTagger(model=lt, backoff=nltk.DefaultTagger('NN'))
    return baseline_tagger.evaluate(brown.tagged_sents(categories='lore'))

def display():
    
    words_by_freq=list(nltk.FreqDist(brown.words(categories='lore')))
    cfd = nltk.ConditionalFreqDist(brown.tagged_words(categories='lore'))
    sizes = 2 ** pylab.arange(15)
    perfs = [performance(cfd, words_by_freq[:size])for size in sizes]
    pylab.plot(sizes, perfs, '-bo')
    pylab.title('Lookup Tagger Performance with Varying Model Size')
    pylab.xlabel('Model Size')
    pylab.ylabel('Performance')
    pylab.show()
display()

# %%
# 28
from nltk.corpus import brown
brown_news_tagged = brown.tagged_words(categories='news', tagset='universal')
fdist = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
print(fdist.items())
print(fdist.most_common())
print(list(fdist))
tag = [tag for (tag, freq) in fdist.most_common()]
print(tag)
freq = [freq for (tag, freq) in fdist.most_common()]
print(freq)
 
 
fdist.plot(cumulative=True)
# Out:
# dict_items([('DET', 11389), ('NOUN', 30654), ('ADJ', 6706), ('VERB', 14399), ('ADP', 12355), ('.', 11928), ('ADV', 3349), ('CONJ', 2717), ('PRT', 2264), ('PRON', 2535), ('NUM', 2166), ('X', 92)])
# [('NOUN', 30654), ('VERB', 14399), ('ADP', 12355), ('.', 11928), ('DET', 11389), ('ADJ', 6706), ('ADV', 3349), ('CONJ', 2717), ('PRON', 2535), ('PRT', 2264), ('NUM', 2166), ('X', 92)]
# ['DET', 'NOUN', 'ADJ', 'VERB', 'ADP', '.', 'ADV', 'CONJ', 'PRT', 'PRON', 'NUM', 'X']
# ['NOUN', 'VERB', 'ADP', '.', 'DET', 'ADJ', 'ADV', 'CONJ', 'PRON', 'PRT', 'NUM', 'X']
# [30654, 14399, 12355, 11928, 11389, 6706, 3349, 2717, 2535, 2264, 2166, 92]

# %%
# 27
pos = {}
print(pos)
pos['colorless'] = 'ADJ'
print(pos)
pos['ideas'] = 'N'
pos['sleep'] = 'V'
pos['furiously'] = 'ADV'
print(pos)
print(pos['ideas'])
# Out:
# {}
# {'colorless': 'ADJ'}
# {'colorless': 'ADJ', 'ideas': 'N', 'sleep': 'V', 'furiously': 'ADV'}
# N

# %%
# 30
import nltk
from nltk.corpus import brown

#我们可以预处理一个文本，在一个默认字典 的帮助下，替换低频词汇为一个特殊的“超出词汇表”标识符，UNK(out of vocabulary)。
 
 
#我们需要创建一个默认字典，映射每个词为它们的替换词。最频繁的n个词将被映射到它们自己。其他的被映射到 UNK。
alice = nltk.corpus.gutenberg.words('carroll-alice.txt')
vocab = nltk.FreqDist(alice)
v1000 = [word for [word, _] in vocab.most_common(1000)]
print(v1000[:5])
 
mapping = nltk.defaultdict(lambda: 'UNK')
for v in v1000:
    mapping[v] = v
alice2 = [mapping[v] for v in alice]
print(alice2[:5])
print(len(set(alice2)))
# Out:
# [',', "'", 'the', 'and', '.']
# ['[', 'Alice', "'", 's', 'Adventures']
# 1001

# %%
# 33

pos = {}
print(pos)
pos['pig'] = 'fat'
print(pos)
pos['apple'] = 'red'
pos['dog'] = 'cute'
pos['money'] = 'good'
print(pos)
print(pos['apple'])
# Out:
# {}
# {'pig': 'fat'}
# {'pig': 'fat', 'apple': 'red', 'dog': 'cute', 'money': 'good'}
# red
