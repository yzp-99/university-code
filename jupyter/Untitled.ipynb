# %%
#  二(3)

import matplotlib.pyplot as plt
import numpy as np

import pandas as pd

f1 = open('data1.csv')
data1 = pd.read_csv(f1)

f2 = open('data2.csv')
data2 = pd.read_csv(f2)


data1.index = pd.to_datetime(data1.index)
data2.index = pd.to_datetime(data2.index)

Data1=data1
Data2=data2
n = False
for i in data2.columns.tolist():
    if i == '时间':
        continue
    fig = plt.figure()
    fig.tight_layout()
    plt.title(i)
    if n:
        try:
            plt.plot(data1[i], label='data1', linestyle='--')
        except:
            pass

        plt.plot(data2[i], label='data2')

    else:
        try:
            plt.plot(data1[i].resample('W-MON').mean(), linestyle='--', label='data1')

        except:
            pass

        plt.plot(data2[i].resample('W-MON').mean(), label='data2')

    plt.legend()
    plt.savefig('均值折线图/' + i + '.jpg')
    plt.show()

# %%
n = False
for i in data2.columns.tolist():
    if i == '时间':
        continue
    fig = plt.figure()
    fig.tight_layout()
    plt.title(i)
    if n:
        try:
            plt.plot(data1[i], label='data1', linestyle='--')
        except:
            pass

        plt.plot(data2[i], label='data2')

    else:
        try:
            plt.plot(data1[i].resample('W-MON').mean(), linestyle='--', label='data1')

        except:
            pass

        plt.plot(data2[i].resample('W-MON').mean(), label='data2')

    plt.legend()
    # plt.savefig('均值折线图/' + i + '.jpg')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-eb3c074c1822> in <module>()
#      21             pass
#      22
# ---> 23         plt.plot(data2[i].resample('W-MON').mean(), label='data2')
#      24
#      25     plt.legend()
#
# E:\Anaconda\anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base, on, level)
#    4727                      axis=axis, kind=kind, loffset=loffset,
#    4728                      convention=convention,
# -> 4729                      base=base, key=on, level=level)
#    4730         return _maybe_process_deprecations(r,
#    4731                                            how=how,
#
# E:\Anaconda\anaconda3\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#     967     """ create a TimeGrouper and return our resampler """
#     968     tg = TimeGrouper(**kwds)
# --> 969     return tg._get_resampler(obj, kind=kind)
#     970
#     971
#
# E:\Anaconda\anaconda3\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1089         raise TypeError("Only valid with DatetimeIndex, "
#    1090                         "TimedeltaIndex or PeriodIndex, "
# -> 1091                         "but got an instance of %r" % type(ax).__name__)
#    1092
#    1093     def _get_grouper(self, obj):
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'
