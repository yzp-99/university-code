# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns


df = pd.read_csv("data1.csv", encoding='gbk')             #读取csv文件
df
# Out:
#       PM2.5  PM10     CO  NO2  SO2   O3                时间
# 0        33    71  0.756    9   25   80  2018/11/14 10:00
# 1        32    69  0.736    9   22   86  2018/11/14 11:00
# 2        33    64  0.804    9   26   88  2018/11/14 12:00
# 3        35    63  0.750    8   26   88  2018/11/14 13:00
# 4        30    69  0.855    8   34   88  2018/11/14 14:00
# 5        33    76  0.763    8   37   89  2018/11/14 15:00
# 6        37    79  0.768    8   47   77  2018/11/14 16:00
# 7        44    82  0.863    8   72   40  2018/11/14 17:00
# 8        48   102  0.876    8   56   50  2018/11/14 18:00
# 9        40    92  0.994    7   81   22  2018/11/14 19:00
# 10       56   112  0.944    8   76   18  2018/11/14 20:00
# 11       51    89  0.862    8   38   56  2018/11/14 21:00
# 12       50    85  0.934    9   36   58  2018/11/14 22:00
# 13       55    85  0.919    9   36   57  2018/11/14 23:00
# 14       50    81  0.873    9   32   59   2018/11/15 0:00
# ...
